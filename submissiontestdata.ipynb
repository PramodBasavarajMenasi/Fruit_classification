# %% [raw]
# import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/submission-testdata/Submission_testdata.csv")

# %%
df
# Out:
#             Label      Predicted
# 0    test_330.png  rotten_banana
# 1    test_441.png  rotten_orange
# 2      test_4.png   fresh_orange
# 3     test_59.png  rotten_banana
# 4    test_201.png   fresh_orange
# ..            ...            ...
# 448  test_432.png  rotten_orange
# 449    test_1.png  rotten_banana
# 450  test_207.png    fresh_apple
# 451   test_37.png  rotten_orange
# 452  test_413.png    fresh_apple
#
# [453 rows x 2 columns]

# %%
df.to_csv('/kaggle/working/Submission_TESTDATA.csv', index=False)
